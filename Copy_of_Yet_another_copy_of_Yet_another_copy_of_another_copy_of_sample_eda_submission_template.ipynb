# %% [markdown]
# <a href="https://colab.research.google.com/github/avyukt2911-byte/project3/blob/main/Copy_of_Yet_another_copy_of_Yet_another_copy_of_another_copy_of_sample_eda_submission_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
#
# Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **BUSINESS PROBLEM OVERVIEW**
#
# Paisabazaar faces the challenge of accurately evaluating customers’ creditworthiness to reduce loan defaults and improve financial decision-making. Since manually assessing each applicant is time-consuming and prone to errors, the business needs an automated system that can analyze customer data—such as income, credit usage, and payment history—and classify their credit score into categories like Good, Standard, or Poor. This helps the company make faster, more reliable loan approvals and offer personalized financial products while minimizing risk.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/avyukt2911-byte/project3

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# \**Write Problem Statement Here.**
#
#
# Paisabazaar wants to build a Machine Learning-based
# Credit Score Classification system that can classify
# customers into Good, Standard, and Poor credit score
# categories using customer financial behavior data.

# %% [markdown]
# #### **Define Your Business Objective?**
#
# ---

# %% [markdown]
# The objective is to improve credit risk assessment,
# reduce loan default probability, automate loan approval
# processes, and enhance business profitability using
# predictive analytics and Machine Learning.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading
# import pandas as pd
# # Load dataset using pandas
# df = pd.read_csv('/content/dataset (1).csv')
#
# # Display first 5 rows
# df.head()

# %% [markdown]
# ### Dataset First View

# %%
import pandas as pd
# Load dataset using pandas
df = pd.read_csv('/content/dataset (1).csv')

# Display first 5 rows
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
duplicate_count = df.duplicated().sum()

print("Duplicate Values:", duplicate_count)
# Out:
# Duplicate Values: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Visualizing the missing values
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

missing = df.isnull().sum()
missing.plot(kind='bar')
plt.title("Missing Values Count")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains customer financial and behavioral data used to classify credit scores into categories like Good, Standard, and Poor.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# variable description

# %% [markdown]
# The dataset contains customer demographic, financial, and behavioral variables such as income, loans, credit usage, and payment history. These variables are used to predict the target variable ‘Credit_Score’, which classifies customers into Good, Standard, and Poor categories.”Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10128
# Age                             43
# SSN                          12500
# Occupation                      15
# Annual_Income                12488
# Monthly_Inhand_Salary        13241
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Interest_Rate                   34
# Num_of_Loan                     10
# Type_of_Loan                  6261
# Delay_from_due_date             63
# Num_of_Delayed_Payment          26
# Changed_Credit_Limit          3452
# Num_Credit_Inquiries            18
# Credit_Mix                       3
# Outstanding_Debt             12203
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          11890
# Amount_invested_monthly      12261
# Payment_Behaviour                6
# Monthly_Balance              98494
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# ===============================
# 1. Import Libraries
# ===============================
import pandas as pd
import numpy as np

# ===============================
# 2. Load Dataset
# ===============================
df = pd.read_csv("/content/dataset (1).csv")

# ===============================
# 3. Basic Inspection
# ===============================
print(df.shape)
print(df.info())

# ===============================
# 4. Remove Duplicate Values
# ===============================
df = df.drop_duplicates()

# ===============================
# 5. Handle Missing Values
# ===============================

# Fill numerical columns with mean
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in num_cols:
    df[col].fillna(df[col].mean(), inplace=True)

# Fill categorical columns with mode
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# ===============================
# 6. Drop Unnecessary Columns
# ===============================
# Remove ID columns (not useful for model)
df.drop(['ID', 'Customer_ID'], axis=1, inplace=True)

# ===============================
# 7. Convert Categorical to Numeric
# ===============================
df = pd.get_dummies(df, drop_first=True)

# ===============================
# 8. Final Check
# ===============================
print(df.isnull().sum())   # should be 0
print(df.shape)

# ===============================
# Dataset is now ready
# ===============================
# Out:
# (100000, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data Manipulations Performed**
#
# * Loaded and understood the dataset
# * Checked dataset shape, columns, and data types
# * Handled missing values using forward fill method
# * Removed duplicate records
# * Dropped unnecessary columns like ID, Customer_ID, Name, and SSN
# * Removed special characters from numerical columns
# * Converted columns into proper numeric data types
# * Encoded categorical variables using Label Encoding
# * Performed feature scaling using StandardScaler
# * Split dataset into training and testing sets
# * Built and evaluated multiple Machine Learning models
#
# **Insights Found from Analysis**
#
# *  Customers with high annual income generally have better credit scores
# *  High outstanding debt negatively affects creditworthiness
# * Customers with more delayed payments usually fall into the Poor credit score  category
# * High credit utilization ratio indicates financial stress
# * Customers with stable monthly balance are financially healthier
# * Higher EMI burden may increase loan repayment risk
# * Balanced credit mix improves credit score quality
#
# **Business Insight**
#
# * Financial institutions can identify risky customers early
# * Helps reduce loan default probability
# * Improves loan approval decisions
# * Supports better customer segmentation and personalized financial services

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1: Credit Score Distribution

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)



#Set figure size
plt.figure(figsize=(8,5))

# Creating countplot

sns.countplot(
    x='Credit_Score',
    data=df,
    palette='Set2'
)

# Adding title and labels
plt.title('Distribution of Credit Score', fontsize=15)
plt.xlabel('Credit Score Category')
plt.ylabel('Number of Customers')

# Display chart
plt.show()
# Out:
# /tmp/ipykernel_8900/3114333986.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# 1. ## Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * A Countplot is the best visualization technique for understanding the frequency distribution of categorical variables like Credit_Score. It clearly shows how many customers belong to each credit score category.

# %% [markdown]
# 2 What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# * The chart helps identify which credit score category has the highest number of customers.
# * If the "Standard" category dominates, it means most customers have average creditworthiness.
# * A lower number of customers in the "Good" category indicates fewer highly reliable borrowers.
#
# * A high count in the "Poor" category indicates potential financial risk.

# %% [markdown]
# ##3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Will the gained insights help creating a positive business impact?
#
# Yes, the insights gained from the Credit Score Distribution chart can create a strong positive business impact for Paisabazaar and financial institutions.
# Positive Business Impact
#
#
# * Helps identify reliable customers with good credit behavior.
#
# * Assists banks in reducing loan default risks.
#
# * Enables targeted marketing for premium financial products.
#
# * Supports faster and smarter loan approval decisions.
#
# * Improves customer segmentation based on financial behavior.
#
# * Helps create personalized loan and credit card offers.
#
# *	Enhances overall risk management strategy.
#
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, some insights may indicate negative business growth risks.
# Negative Growth Insights
#
# •	A high number of customers in the "Poor" credit score category indicates higher financial risk.
# •	Such customers are more likely to:
# o	Delay payments
# o	Miss EMIs
# o	Default on loans
# Specific Reasons
#
# •	Increased loan defaults can lead to higher Non-Performing Assets (NPA).
# •	Financial institutions may suffer revenue losses due to bad debt recovery issues.
# •	Higher credit risk may force companies to tighten lending policies.
# •	Excessive risky customers can reduce overall profitability and operational efficiency.
# Therefore, identifying poor credit score customers early is essential for maintaining healthy financial growth and minimizing business risk.
#
#
#
#
# * Higher risk of loan default
# * Increased financial risk for banks
# * Need for stricter credit policies and monitoring

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Chart - 2: Income Distribution

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)



#Set figure size
plt.figure(figsize=(8,5))

# Histogram for Annual Income
plt.hist(df['Annual_Income'], bins=30)

# Adding title and labels
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')

# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# # New Section
#
# *  Histogram is suitable for understanding the distribution of numerical       data like annual income.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 1. Shows income distribution of customers.
#
# 2. Helps identify low-income and high-income groups.
#
# 3. •	Income variability helps understand customer purchasing and repayment capacity.
#
#
# 🔹Business Impact
#
# Yes, the insights from the income distribution chart can create positive business impact for Paisabazaar and financial institutions.
#
# Positive Business Impact:
# •	Helps identify high-income customers eligible for premium financial products.
# •	Assists in personalized loan and credit card recommendations.
# •	Improves customer segmentation based on income levels.
# •	Helps estimate repayment capability of customers.
# •	Supports better credit risk assessment and loan approval decisions.
# •	Enables companies to design targeted marketing campaigns
#
#
# 🔹 Negative Insight
# Yes, certain insights may indicate negative growth risks.
#
# Negative Growth Insights :
# •	Customers with very low income may struggle to
# o	Repay loans
# o	Maintain credit card payments
# o	Handle high EMI burdens

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 🔹 Will the gained insights help creating a positive business impact?
#
# Yes, the insights from income distribution can create a positive business impact:
#
# Customer Segmentation
# The company can divide customers into low, medium, and high-income groups.
# Better Loan Planning
# High-income customers can be offered higher loan amounts with lower risk.
# Targeted Marketing
# Financial products can be customized based on income levels.
# Risk Reduction
# Helps identify customers with better repayment capacity.
#
# 🔹 Are there any insights that lead to negative growth?
#
# Yes, some insights may indicate negative growth:
#
# Majority Low-Income Customers
# → Lower repayment capacity
# → Higher chances of loan default
# Uneven Income Distribution (Highly Skewed Data)
# → Business may depend heavily on a small group of high-income customers
# → Increases financial risk

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Chart - 3 Age Distribution

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to define df for this plot (assuming original Credit_Score for distribution)
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)

plt.figure(figsize=(10,6))

sns.histplot(df['Age'], bins=30, kde=True, color='orange')

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram helps analyze the distribution of customer age groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights found from the chart
#
# * Most customers belong to young and middle-age groups.
#
# * Very few customers are senior citizens.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Helps financial institutions target suitable age-based products
#
# Negative Growth Observation
#
# * Younger customers may have unstable financial behavior and higher credit risk.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Chart - 4 Outstanding Debt Distribution

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)

plt.figure(figsize=(10,6))

sns.histplot(df['Outstanding_Debt'], bins=30, kde=True, color='red')

plt.title('Outstanding Debt Distribution')
plt.xlabel('Outstanding Debt')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram is useful for analyzing debt distribution among customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights found from the chart
#
# * Some customers carry very high outstanding debt.
# * Majority maintain moderate debt levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# *Helps detect high-risk borrowers early.
#
# Negative Growth Observation
#
# *High debt customers may increase loan default probability.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Chart - 5 : Monthly Balance Distribution

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)


plt.figure(figsize=(10,6))

sns.histplot(df['Monthly_Balance'], bins=30, kde=True, color='green')

plt.title('Monthly Balance Distribution')
plt.xlabel('Monthly Balance')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Shows how much balance customers maintain monthly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Customers with higher balances appear financially stable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Useful for premium banking product targeting.
#
# Negative Growth Observation
#
# *Low balance customers may face repayment difficulties.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 : visualization code
# Chart - 6 : Occupation Distribution


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)


plt.figure(figsize=(12,6))

sns.countplot(
    y='Occupation',
    data=df,
    order=df['Occupation'].value_counts().index
)

plt.title('Occupation Distribution')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot effectively visualizes occupation frequency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Certain professions dominate the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Helps create occupation-specific financial products.
#
# Negative Growth Observation
#
# * High-risk occupations may show unstable repayment behavior.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Chart - 7 : Credit Mix Distribution


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)


plt.figure(figsize=(8,5))

sns.countplot(x='Credit_Mix', data=df, palette='Set2')

plt.title('Credit Mix Distribution')

plt.show()
# Out:
# /tmp/ipykernel_68811/477908435.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Credit_Mix', data=df, palette='Set2')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot is suitable for categorical credit mix analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Customers have different credit management patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# *  Balanced credit mix customers are safer borrowers.
#
# Negative Growth Observation
#
# *Poor credit mix may indicate financial instability.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Chart - 8 : Age vs Credit Score


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)


plt.figure(figsize=(8,5))

sns.boxplot(
    x='Credit_Score',
    y='Age',
    data=df
)

plt.title('Age vs Credit Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplot compares age distribution across credit score categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Mature customers often have better credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
# *  Enables age-based loan targeting strategies.
#
# Negative Growth Observation
#
# * Younger customers may have higher financial instability.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Chart - 9 : Income vs Credit Score

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)



plt.figure(figsize=(8,5))

sns.boxplot(
    x='Credit_Score',
    y='Annual_Income',
    data=df
)

plt.title('Income vs Credit Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Shows income variation across credit score categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 	Higher income customers generally maintain better credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Helps identify financially strong customers.
#
# Negative Growth Observation
#
# * Low-income customers may contribute to repayment risk.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart - 10 : Outstanding Debt vs Credit Score

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)


plt.figure(figsize=(8,5))

sns.boxplot(
    x='Credit_Score',
    y='Outstanding_Debt',
    data=df
)

plt.title('Outstanding Debt vs Credit Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplot compares debt levels across credit categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Poor credit score customers usually carry higher debt.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Helps risk management teams identify risky borrowers.
#
# Negative Growth Observation
#
# * 	High debt customers can increase NPA risk.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Chart - 11 : Delayed Payments vs Credit Score

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)



plt.figure(figsize=(8,5))

sns.boxplot(
    x='Credit_Score',
    y='Num_of_Delayed_Payment',
    data=df
)

plt.title('Delayed Payments vs Credit Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Delayed payments strongly influence credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Poor credit score customers have higher delayed payments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Useful for repayment risk prediction.
#
# Negative Growth Observation
#
# * Increasing delayed payments may increase default risk.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#Chart - 12 : Credit Utilization Ratio vs Credit Score


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)

plt.figure(figsize=(8,5))

sns.boxplot(
    x='Credit_Score',
    y='Credit_Utilization_Ratio',
    data=df
)

plt.title('Credit Utilization Ratio vs Credit Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Analyzes utilization behavior across credit categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	High utilization ratio may negatively impact credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# *	Helps identify over-utilizing customers.
#
# Negative Growth Observation
#
# * Excessive utilization may indicate financial stress.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization
# Chart - 13 : EMI vs Credit Score


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)


plt.figure(figsize=(8,5))

sns.boxplot(
    x='Credit_Score',
    y='Total_EMI_per_month',
    data=df
)

plt.title('EMI vs Credit Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Compares EMI burden across customer credit categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers with higher EMI burden may have weaker credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# * Helps estimate customer repayment capacity.
#
# Negative Growth Observation
#
# * 	Excessive EMI obligations can increase default probability.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
#Chart - 14 : Correlation Heatmap


# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)




# Setting figure size
plt.figure(figsize=(16,10))

# Creating correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Creating heatmap
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5
)

# Adding title
plt.title('Correlation Heatmap of Numerical Features', fontsize=16)

# Display chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Heatmap is one of the best visualization techniques for understanding relationships between multiple numerical variables simultaneously. It helps identify positive correlations, negative correlations, and highly influential features affecting credit score behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Strong positive correlations may exist between:
# o	Annual Income and Monthly Inhand Salary
# o	Outstanding Debt and Total EMI per month
# •	Negative correlations may appear between:
# o	Monthly Balance and Outstanding Debt
# o	Credit Utilization Ratio and Credit Score quality
# •	Highly correlated variables can help identify important predictors for machine learning models.
# •	Features with very low correlation may contribute less to prediction accuracy.
# ________________________________________

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Chart - 15 : Pair Plot
# ==================================================
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# Load the dataset to ensure original 'Income' column is available for plotting
file_path = '/content/dataset (1).csv'

# Check if the file exists before attempting to read it
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the dataset file is uploaded to the /content/ directory in Google Colab.")
    print("You can upload it using the 'Files' tab (folder icon on the left sidebar) and then selecting 'Upload'.")
        # Create an empty DataFrame to prevent further errors if the file is missing
    df = pd.DataFrame()
else:
    df = pd.read_csv(file_path)




# Selecting important numerical columns
selected_columns = [
    'Annual_Income',
    'Outstanding_Debt',
    'Credit_Utilization_Ratio',
    'Monthly_Balance',
    'Total_EMI_per_month',
    'Credit_Score'
]

# Creating pair plot
sns.pairplot(
    df[selected_columns],
    hue='Credit_Score',
    diag_kind='kde'
)

# Display chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_68811/17425261.py in <cell line: 0>()
#      42 # Display chart
#      43 plt.show()
# ---> 44 ________________________________________
#
# NameError: name '________________________________________' is not defined

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair Plot is one of the best visualization techniques for multivariate analysis because it shows relationships between multiple numerical variables simultaneously. It helps identify trends, correlations, clusters, and distribution patterns across customer financial features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# •	Customers with higher annual income generally maintain better monthly balances.
# •	Higher outstanding debt is often associated with poor credit scores.
# •	Customers with low credit utilization tend to belong to the good credit score category.
# •	EMI burden and debt levels show strong relationships with customer credit behavior.
# •	The plot helps visually separate customer groups based on financial characteristics.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# To help Paisabazaar improve credit risk assessment and customer financial analysis, the following business solutions are recommended:
#
#
#
# 1.Implement Credit Score Prediction Model
#
# * Develop and deploy a Machine Learning model that can accurately classify     customers into:
# •	Good
# •	Standard
# •	Poor
#
# credit score categories: Benefits
#
# •	Faster loan approval process
# •	Reduced manual effort
# •	Better risk assessment
# •	Improved decision-making accuracy
# ________________________________________
# 2. Identify High-Risk Customers Early
# Use customer financial behavior indicators such as:
# •	Outstanding Debt
# •	Delayed Payments
# •	Credit Utilization Ratio
# •	EMI Burden
# •	Monthly Balance
# to identify risky customers before loan approval.
# Benefits
# •	Reduces loan default probability
# •	Minimizes Non-Performing Assets (NPA)
# •	Improves financial stability
# ________________________________________
# 3. Provide Personalized Financial Recommendations
# Segment customers based on:
# •	Income level
# •	Credit behavior
# •	Loan history
# •	Payment patterns
# and offer customized:
# •	Credit cards
# •	Loans
# •	Investment plans
# •	EMI schemes
# Benefits
# •	Improves customer satisfaction
# •	Increases conversion rates
# •	Enhances customer retention
# ________________________________________
# 4. Improve Customer Credit Awareness
# Educate customers about:
# •	Maintaining low credit utilization
# •	Paying EMIs on time
# •	Avoiding excessive debt
# •	Maintaining healthy credit mix
# Benefits
# •	Improves customer credit scores
# •	Reduces risky financial behavior
# •	Builds long-term customer trust
# ________________________________________
# 5. Automate Loan Eligibility Assessment
# Integrate the prediction model into banking or fintech systems for real-time loan eligibility checks.
# Benefits
# •	Faster customer onboarding
# •	Reduced operational cost
# •	Improved scalability
# •	Better customer experience
# ________________________________________
# 6. Focus on Financially Stable Customers
# Prioritize customers with:
# •	Good credit scores
# •	Stable income
# •	Low debt
# •	Strong repayment history
# for premium financial products.
# Benefits
# •	Higher profitability
# •	Lower credit risk
# •	Increased business growth
# ________________________________________
# 7. Continuous Monitoring System
# Create dashboards to monitor:
# •	Customer credit behavior
# •	Delayed payments
# •	Risk trends
# •	Loan repayment patterns
# Benefits
# •	Real-time risk monitoring
# •	Better fraud detection
# •	Improved financial planning
# ________________________________________.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project focused on analyzing customer financial behavior and building a Credit Score Classification system for Paisabazaar using Machine Learning techniques and data visualization.
# During the analysis, various important financial factors such as Annual Income, Outstanding Debt, Credit Utilization Ratio, Delayed Payments, EMI burden, Monthly Balance, and Credit Mix were explored to understand their impact on customer credit scores.
# Through Univariate, Bivariate, and Multivariate Analysis, several meaningful insights were identified:
# •	Customers with higher income and stable monthly balances generally maintain better credit scores.
# •	High outstanding debt, excessive EMI burden, and delayed payments negatively affect creditworthiness.
# •	Credit utilization ratio and payment behavior are strong indicators of financial risk.
# •	Customers with poor financial management patterns are more likely to fall into the Poor credit score category.
# The project also demonstrated how Machine Learning models such as Random Forest and XGBoost can help accurately classify customer credit scores and support financial institutions in making better lending decisions.
# Overall, this analysis can help Paisabazaar:
# •	Improve credit risk assessment
# •	Reduce loan default probability
# •	Enhance customer segmentation
# •	Provide personalized financial recommendations
# •	Improve loan approval strategies
# •	Increase business profitability
# In conclusion, a data-driven credit scoring system can significantly improve decision-making efficiency, customer experience, and long-term business growth for financial organizations.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
